# %%
import google.generativeai as genai

# Configure your Gemini API key
genai.configure(api_key="AIzaSyDQLPtP-uc8sWqHp8ybDhog8hFEDE3EJKM") ## placeholder API
embedding_model = "models/embedding-001"

# %%
# Choose model (fast = flash, powerful = pro)
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
response = model.generate_content("Hello")
print(response.text)
# Out:
# Hello there! How can I help you today?

# %%
chat = model.start_chat(history=[])
response = chat.send_message("Hello")
print(response.text)
# Out:
# Hello there! How can I help you today?

# %%
text = "Artificial Intelligence will transform the world."

result = genai.embed_content(
    model=embedding_model,
    content=text,
)

# The embedding vector
embedding = result["embedding"]
print(len(embedding), embedding[:10])  # length + first 10 values
# Out:
# 768 [-0.005194688, -0.011535946, -0.013198904, -0.021250233, 0.05627057, 0.017312866, 0.02318359, -0.0088782655, 0.01705779, 0.03492125]

# %% [markdown]
# Test GPT model

# %%
text = "Artificial Intelligence will transform the world."

result = genai.embed_content(
    model=embedding_model,
    content=text,
)

# The embedding vector
embedding = result["embedding"]
print(len(embedding), embedding[:10])  # length + first 10 values
# Out:
# 768 [-0.005194688, -0.011535946, -0.013198904, -0.021250233, 0.05627057, 0.017312866, 0.02318359, -0.0088782655, 0.01705779, 0.03492125]

# %% [markdown]
# Test embedding model

# %%
texts = ["AI is powerful", "The sky is blue", "I love pizza"]

results = [genai.embed_content(model=embedding_model, content=t)["embedding"] for t in texts]

print(len(results), len(results[0]))  # number of embeddings, dimension
# Out:
# 3 768
